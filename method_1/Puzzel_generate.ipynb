# %%
# directly use this to find contour coordinates and plot 
import matplotlib.pyplot as plt

# plt.plot(coordinates)
import cv2
import matplotlib.pyplot as plt

# Read the image
image = cv2.imread("test_1_black_cont.png")

# Convert the image to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Find contours in the image
contours, _ = cv2.findContours(gray, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

# Assuming you have only one contour (change the index if you have multiple)
contour = contours[0]

# Get the coordinates of the contour points
x_coords = [point[0][0] for point in contour]
y_coords = [point[0][1] for point in contour]

# Plot the contour
plt.figure(figsize=(6, 6))
plt.plot(x_coords, y_coords, '-b', linewidth=0.5)
print(len(x_coords))
plt.gca().invert_yaxis()  # Invert y-axis to match image coordinates
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title('Contour Coordinates')
plt.grid()
plt.show()
# Out:
# 745

# %%
import cv2

# if u have multiple contours , so make sure your only have one 
# Read the image
image = cv2.imread("test_1_black_cont.png")

# Convert the image to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply binary thresholding to create a mask
_, mask = cv2.threshold(gray, 1, 255, cv2.THRESH_BINARY)

# Find contours
contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

# Print the coordinates of the first contour (assuming it's the rectangle)
if len(contours) > 0:
    # Extract the coordinates of the first contour
    contour_coordinates = contours[0][:, 0, :].tolist()
    
    # Print the coordinates
    print("Contour Coordinates:")
    for coordinate in contour_coordinates:
        print(coordinate)
else:
    print("No contour found in the image.")
print(len(contour_coordinates))
# Out:
# Contour Coordinates:
# [201, 39]
# [201, 40]
# [201, 41]
# [201, 42]
# [201, 43]
# [201, 44]
# [201, 45]
# [201, 46]
# [201, 47]
# [201, 48]
# [201, 49]
# [201, 50]
# [201, 51]
# [201, 52]
# [201, 53]
# [201, 54]
# [201, 55]
# [201, 56]
# [201, 57]
# [201, 58]
# [201, 59]
# [201, 60]
# [201, 61]
# [201, 62]
# [201, 63]
# [201, 64]
# [201, 65]
# [201, 66]
# [201, 67]
# [201, 68]
# [201, 69]
# [201, 70]
# [201, 71]
# [201, 72]
# [201, 73]
# [201, 74]
# [201, 75]
# [201, 76]
# [201, 77]
# [201, 78]
# [201, 79]
# [201, 80]
# [201, 81]
# [201, 82]
# [201, 83]
# [201, 84]
# [201, 85]
# [201, 86]
# [201, 87]
# [201, 88]
# [201, 89]
# [201, 90]
# [201, 91]
# [201, 92]
# [201, 93]
# [201, 94]
# [201, 95]
# [201, 96]
# [201, 97]
# [201, 98]
# [201, 99]
# [201, 100]
# [201, 101]
# [201, 102]
# [201, 103]
# [201, 104]
# [201, 105]
# [201, 106]
# [201, 107]
# [201, 108]
# [201, 109]
# [201, 110]
# [201, 111]
# [201, 112]
# [201, 113]
# [201, 114]
# [201, 115]
# [201, 116]
# [201, 117]
# ...

# %%
points = all_contour_coordinates

x_coordinates = [point[0] for point in points]
y_coordinates = [point[1] for point in points]

print("X coordinates:", x_coordinates)
print("Y coordinates:", y_coordinates)
# Out:
# X coordinates: [201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 201, 200, 199, 198, 197, 196, 195, 194, 193, 192, 191, 190, 189, 188, 187, 186, 185, 184, 183, 182, 181, 180, 179, 178, 177, 176, 175, 174, 17
# ...

# %%
plt.gca().invert_yaxis() 
plt.plot(x_coordinates,y_coordinates)
