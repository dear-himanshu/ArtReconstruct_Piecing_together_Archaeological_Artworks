# %%
import cv2 
import numpy as np 
import matplotlib.pyplot as plt

# %%
Gray_image = cv2.imread('frag_1.png',0)

plt.figure(figsize=[10,10])
plt.imshow(Gray_image, cmap= 'gray');plt.title("Original Image");plt.axis("off");
